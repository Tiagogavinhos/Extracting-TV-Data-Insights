# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiagogavinhos/Extracting-TV-Data-Insights/blob/main/Extracting_TV_Data_Insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# All datasets are available to my Google Drive.

from google.colab import drive
drive.mount('/content/drive')

# Loading 'super_bowls.csv'
super_bowls = pd.read_csv('/content/drive/MyDrive/Open Projects/datasets/Extracting TV Data Insights/super_bowls.csv')
super_bowls.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          date  super_bowl                          venue             city  \
# 0  2018-02-04          52              U.S. Bank Stadium      Minneapolis
# 1  2017-02-05          51                    NRG Stadium          Houston
# 2  2016-02-07          50                 Levi's Stadium      Santa Clara
# 3  2015-02-01          49  University of Phoenix Stadium         Glendale
# 4  2014-02-02          48                MetLife Stadium  East Rutherford
#
#         state  attendance           team_winner  winning_pts     qb_winner_1  \
# 0   Minnesota       67612   Philadelphia Eagles           41      Nick Foles
# 1       Texas       70807  New England Patriots           34       Tom Brady
# 2  California       71088        Denver Broncos           24  Peyton Manning
# 3     Arizona       70288  New England Patriots           28       Tom Brady
# ...

# %%
# Loading 'tv.csv'

tv = pd.read_csv("/content/drive/MyDrive/Open Projects/datasets/Extracting TV Data Insights/tv.csv")
tv.head()
# print (tv)
# type(tv)
# Out:
#    super_bowl network  avg_us_viewers  total_us_viewers  rating_household  \
# 0          52     NBC       103390000               NaN              43.1
# 1          51     Fox       111319000       172000000.0              45.3
# 2          50     CBS       111864000       167000000.0              46.6
# 3          49     NBC       114442000       168000000.0              47.5
# 4          48     Fox       112191000       167000000.0              46.7
#
#    share_household  rating_18_49  share_18_49  ad_cost
# 0               68          33.4         78.0  5000000
# 1               73          37.1         79.0  5000000
# 2               72          37.7         79.0  5000000
# 3               71          39.1         79.0  4500000
# 4               69          39.3         77.0  4000000

# %%
# Loading 'halftime_muscians.csv'

halftime_musicians = pd.read_csv("/content/drive/MyDrive/Open Projects/datasets/Extracting TV Data Insights/halftime_musicians.csv")
halftime_musicians.head()
# Out:
#    super_bowl                               musician  num_songs
# 0          52                      Justin Timberlake       11.0
# 1          52  University of Minnesota Marching Band        1.0
# 2          51                              Lady Gaga        7.0
# 3          50                               Coldplay        6.0
# 4          50                                Beyoncé        3.0

# %%
# Questions to be answered:
# Has TV viewership increased over time?

# Find the year with the highest TV viewership
plt.plot(tv.super_bowl, tv.avg_us_viewers)
plt.title('Average Number of US Viewers')
plt.xlabel('Super Bowl Number')
plt.ylabel('Average US Viewers')
# viewership_increased = True
print(f"Super Bowl viewership increased over time but is not a linear relationship.")
# Out:
# Super Bowl viewership increased over time but is not a linear relationship.

# %%
# Second question
# How many matches finished with a point difference greater than 40?

# Question 2
# Display the Super Bowls data to inspect
super_bowls.head()

# %%
# Second question
# How many matches finished with a point difference greater than 40?
# Continuation of second question

# Filter the data for point difference >40
# difference = len(super_bowls[super_bowls["difference_pts"]>40])

test = super_bowls[super_bowls["difference_pts"]>40]
print("Tipo da variavel teste",type(test))
print(test)


# Filter the data for point difference >40
difference = super_bowls[super_bowls["difference_pts"]>40]

# super_bowls["difference_pts"]>40 => Create a boolean mask
# where it is stated "True' or 'False' accordance witht the operation
# super_bowls[super_bowls["difference_pts"]>40] => Return only the
# value True

# As 'difference' is a Dataframe it is not clear the result for us.

print("\n")
print("How many lines are affected: ",len(difference))
print("\n")
# The function len () count how many lines has presenton Dataframe

# You can also plot a histogram of point differences to visualize the result
plt.hist(super_bowls.difference_pts)
plt.xlabel('Point Difference')
plt.ylabel('Number of Super Bowls')
plt.show()

# Alternativa for the solution above
difference_A = super_bowls[super_bowls["difference_pts"] > 40].shape[0]
print("How many lines are affected_A: ", difference_A)
# Out:
# Tipo da variavel teste <class 'pandas.core.frame.DataFrame'>
#           date  super_bowl                venue         city      state  \
# 28  1990-01-28          24  Louisiana Superdome  New Orleans  Louisiana
#
#     attendance          team_winner  winning_pts  qb_winner_1 qb_winner_2  \
# 28       72919  San Francisco 49ers           55  Joe Montana         NaN
#
#       coach_winner      team_loser  losing_pts  qb_loser_1 qb_loser_2  \
# 28  George Seifert  Denver Broncos          10  John Elway        NaN
#
#    coach_loser  combined_pts  difference_pts
# 28  Dan Reeves            65              45
#
#
# How many lines are affected:  1
# How many lines are affected_A:  1

# %%
# Who performed the most songs in Super Bowl halftime shows?

import pandas as pd

# Create a sample DataFrame
data = {'col1': [1, 2, 3], 'col2': [4, 5, 6]}
df = pd.DataFrame(data)

print(type(data))
print(type(df))

# Get the shape of the DataFrame
print(df.shape)
# Out:
# <class 'dict'>
# <class 'pandas.core.frame.DataFrame'>
# (3, 2)
